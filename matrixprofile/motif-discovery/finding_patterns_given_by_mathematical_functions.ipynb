# %% [markdown]
# # Finding patterns given by mathematical functions
#
# This interactive application shows how [Khiva library](https://khiva-python.readthedocs.io/en/latest/) can help you to discover patterns in a large sequence.

# %%
import matplotlib.pyplot as plt
import khiva as kv
from random import randint
from ipywidgets import interact, IntSlider, widgets 
import math
import numpy as np

# %config IPCompleter.greedy=True
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 5]

# %% [markdown]
# ## Backend
# Prints the backend being used. The CPU, CUDA and OPENCL backends are available in Khiva.
#
# > This interactive application is being executed in **hub.mybinder** which doesn't provide a GPU and its CPU is limited.

# %%
print(kv.get_backend())
# Out:
# KHIVABackend.KHIVA_BACKEND_OPENCL

# %% [markdown]
# ## Time series generation
# Next cell generates a random sequence of 10000 data points.

# %%
time_series = np.random.rand(10000)
plt.plot(range(len(time_series)), time_series)
plt.title("Random Sequence")
plt.show()

# %% [markdown]
# ## Pattern discovery
#
# Now, you can select the target function that you want find in the large random sequence previously generated.
#
# The next two plots show the selected target pattern and the most similar subsequence respectively. You can select a target pattern among all the following functions: f(x)=x, f(x)=√x, f(x)=x^2, f(x)=x^3, f(x)=log(x).
#
# Then, we execute the [**stomp()**](https://khiva-python.readthedocs.io/en/latest/khiva.html#khiva.matrix.stomp) method to compute the matrix profile. Later, we execute the [**find_best_n_motifs()**](https://khiva-python.readthedocs.io/en/latest/khiva.html#khiva.matrix.find_best_n_motifs) method to plot the most similar subsequence.

# %%
def discover_motif(function, range_selected):
    subsequence = []
    range_selected = list(range_selected)
    if(function == "n"):
        [subsequence.append(i) for i in range(range_selected[0], range_selected[1] + 1)]
    elif(function == "√n"):
        if(range_selected[0]<0):
            print("INFO: Minimum value changed to 0 for this function.")
            range_selected[0] = 0
        [subsequence.append(i**(1/2)) for i in range(range_selected[0], range_selected[1] + 1)]
    elif(function == "n^2"):
        [subsequence.append(i*i) for i in range(range_selected[0], range_selected[1] + 1)]
    elif(function == "n^3"):
        [subsequence.append(i*i*i) for i in range(range_selected[0], range_selected[1] + 1)]
    elif(function == "log(n)"):
        if(range_selected[0]<=0):
            print("INFO: Minimum value changed to 1 for this function.")
            range_selected[0] = 1
        [subsequence.append(math.log(i)) for i in range(range_selected[0], range_selected[1] + 1)]
    
    a = kv.Array(time_series, khiva_type=kv.dtype.f64)
    b = kv.Array(subsequence, khiva_type=kv.dtype.f64)

    distance, profile = kv.stomp(a, b, len(range(range_selected[0], range_selected[1])))
    distance_motif, index_motif, index_subsequence_motif = kv.find_best_n_motifs(distance, profile, len(range(range_selected[0], range_selected[1])), 1)

    index_motif = index_motif.to_numpy()
    a = a.to_numpy()
    window=len(range_selected)//2
   
    plt.plot(range(range_selected[0], range_selected[1] +1), subsequence)
    plt.title("Selected pattern")
    plt.show()
    
    plt.plot(range(index_motif[0] - window, index_motif[0] + window), a[index_motif[0] -window:index_motif[0] + window])
    plt.plot(range(index_motif[0], (index_motif[0] + len(range(range_selected[0], range_selected[1] + 1)))), a[index_motif[0]: (index_motif[0] + len(range(range_selected[0], range_selected[1] +1)))])
    plt.title("Most similar subsequence")
    plt.show()

interact(discover_motif,  
        function = widgets.Dropdown(
        options=['n', "√n", "n^2", "n^3", "log(n)"],
        value='n',
        description='Function:',
        disabled=False,
    ), 
        range_selected = widgets.IntRangeSlider(
        value=[0, 6],
        min=-15,
        max=15,
        step=1,
        description='Range:',
        disabled=False,
        continuous_update=False,
        orientation='horizontal',
        readout=True,
        readout_format='.1f',
    ));
# Out:
# interactive(children=(Dropdown(description='Function:', options=('n', '√n', 'n^2', 'n^3', 'log(n)'), value='n'…
